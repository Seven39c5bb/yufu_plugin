# %%
import os
import random
plugin_root_dir = os.getcwd()
image_path = os.path.join(plugin_root_dir, 'asset', 'img', 'llt')
if os.path.exists(image_path):
    print('yes')
    all_items = os.listdir(image_path)
    image_files = [f for f in all_items if os.path.isfile(os.path.join(image_path, f))]
    random_image_name = random.choice(image_files)
    image_path_fin = os.path.join(plugin_root_dir, 'asset', 'img', 'llt',random_image_name)
    print(image_path_fin)
# Out:
# yes
# 1.jpg
